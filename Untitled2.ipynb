# %%
# Лабораторная работа №1
## Выполнил студент группы 1бПМ2 Яхненко Алексей Вадимович
### Задание №2
#### Написать генератор случайных матриц (многомерных), который принимает
####опциональныепараметры​m,n,min_limit,max_limit,где m и n nуказывают размер матрицы,min_lim​и max_lim-минимальноеимаксимальноезначениедлягенерируемогочисла.Поумолчанию при отсутствии параметров принимать следующие значения :

import random
def creatArray():
    r=0
    print("Input first index matrix")
    x = int(input())
    print("Input second index matrix")
    y = int(input())
    array=[]
    min_limit = -250
    max_limit = 1000 + (13)
    #1
    for i in range (x):
        array.append([])
        for j in range(y):
            array[i].append(random.randint(min_limit,max_limit))
            r+=1
    #2
    print("Matrix:")
    for u in range(x):
        print(array[u])
    
  
creatArray()
# Out:
# Input first index matrix
# 5
# Input second index matrix
# 5
# Matrix:
# [669, 261, -102, -25, -58]
# [-45, 407, 948, -157, 276]
# [197, 923, -18, -98, 955]
# [258, 43, 220, 740, -209]
# [-22, 727, -182, 332, 112]
